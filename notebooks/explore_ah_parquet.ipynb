# %%
import duckdb

duck = duckdb.connect()  # in-memory DB

df = duck.execute(
    """
    SELECT * FROM read_parquet("/tmp/wow-analytics/eu/connected_realms.parquet");
    """).df()

print(df)
# Out:
#     connected_realm_id  has_queue status_type population_type  num_realms  \
# 0                 1080      False          UP             LOW           2
# 1                 1084      False          UP            FULL           2
# 2                 1596      False          UP          MEDIUM           6
# 3                 1597      False          UP            HIGH           4
# 4                 1598      False          UP             LOW          10
# ..                 ...        ...         ...             ...         ...
# 87                3686      False          UP            FULL           1
# 88                3690      False          UP     RECOMMENDED           1
# 89                3691      False          UP            FULL           4
# 90                3692      False          UP            HIGH           1
# 91                3696      False          UP            HIGH           4
#
#                                           realm_names  \
# ...
